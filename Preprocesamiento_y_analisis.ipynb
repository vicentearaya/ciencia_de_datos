# %% [markdown]
# # Preprocesamiento y visualizacion del dataset
#
# El objetivo de este notebook es documentar, de forma ordenada y comprensible, el proceso de revision, limpieza y transformacion del dataset de gaming y salud mental. La estructura esta organizada por etapas para que cada decision de preprocesamiento quede justificada y sea facil de seguir en el contexto de una tarea academica.

# %% [markdown]
# ## 0. Contexto, problem�tica, objetivos y KPIs
#
# ### Contexto
#
# El gaming se ha consolidado como una de las actividades de ocio m�s extendidas a nivel global. Con el aumento de horas de juego, el debate acad�mico y cl�nico sobre su relaci�n con indicadores de salud mental �ansiedad, depresi�n, soledad, adicci�n� ha ganado relevancia. Sin embargo, muchos estudios carecen de datos representativos o no cuantifican con precisi�n los factores de riesgo conductuales.
#
# ### Problem�tica
#
# Las organizaciones de salud, las plataformas de gaming y los equipos de bienestar corporativo necesitan comprender qu� patrones de comportamiento en jugadores est�n asociados a resultados negativos en salud mental. Sin esa informaci�n, los programas de intervenci�n son gen�ricos e ineficaces.
#
# > **Pregunta anal�tica:** �Cu�les son los factores de comportamiento de juego (horas, intensidad, contexto social, h�bitos) que mejor predicen niveles elevados de ansiedad, depresi�n y adicci�n en jugadores, y cu�les variables presentan el mayor riesgo de calidad en el dataset?
#
# ### Objetivos SMART
#
# | # | Objetivo | Espec�fico | Medible | Alcanzable | Relevante | Temporal |
# |---|----------|-----------|---------|-----------|----------|---------|
# | O1 | Realizar un perfil completo de calidad del dataset (completitud, consistencia, outliers) | Dataset de 10M registros y 40 variables | % de valores inv�lidos por columna, # duplicados | Con herramientas de pandas y Python | Prepara datos para modelado | Tarea 1 |
# | O2 | Identificar las variables con mayor correlaci�n con `addiction_level`, `anxiety_score` y `depression_score` | Variables num�ricas del dataset | Correlaci�n de Pearson >= 0.10 | Mediante EDA estad�stico | Orienta la selecci�n de features | Tarea 1 |
# | O3 | Construir un pipeline reproducible de preprocesamiento que transforme el dataset crudo en un conjunto listo para modelado | Dataset procesado sin nulos ni outliers extremos | Script ejecutable con par�metros configurables | Con scikit-learn y pandas | Garantiza reproducibilidad | Tarea 1 |
# | O4 | Evaluar la distribuci�n y comportamiento de indicadores de salud mental por segmento de g�nero y edad | Variables demogr�ficas disponibles | Distribuciones visuales + estad�sticos descriptivos | Con matplotlib | Identifica heterogeneidad en la muestra | Tarea 1 |
#
# ### KPIs y criterios de �xito
#
# | KPI | Definici�n | Umbral de �xito |
# |-----|-----------|----------------|
# | **Tasa de valores inv�lidos** | % de registros con al menos un valor fuera de rango | < 0.5% del total |
# | **Completitud post-imputaci�n** | % de celdas no nulas en el dataset final | 100% |
# | **Correlaci�n m�xima con addiction_level** | Mayor correlaci�n absoluta de Pearson entre variables predictoras y la variable objetivo | Identificar >= 3 variables con r >= 0.10 |
# | **Reproducibilidad del pipeline** | El script `preprocess_dataset.py` ejecuta sin errores con el dataset original | Ejecuci�n exitosa en entorno limpio |
# | **Cobertura del DQR** | N�mero de dimensiones de calidad documentadas (completitud, consistencia, unicidad, validez, riesgos) | >= 5 dimensiones |

# %% [markdown]
# ## 1. Librerias y configuracion
#
# En primer lugar se importan las librerias necesarias para el analisis y se fijan algunos parametros de trabajo. Se utiliza una muestra amplia del dataset para mantener un equilibrio entre representatividad y tiempo de ejecucion.

# %%
import os
from pathlib import Path


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("ggplot")
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

DATASET_PATH = Path("RAW/gaming_mental_health_10M_40features.csv.gz")
SAMPLE_ROWS = 200_000
SAVE_PROCESSED = True
PROCESSED_OUTPUT = Path("processed/dataset_preprocessed.csv")

# %% [markdown]
# ## 2. Carga del dataset
#
# En esta etapa se carga el archivo original desde la carpeta `RAW`. Para facilitar la exploracion inicial, se trabaja con una muestra del conjunto de datos. Si se requiere un analisis completo, el parametro `SAMPLE_ROWS` puede cambiarse a `None`.

# %%
df = pd.read_csv(DATASET_PATH, nrows=SAMPLE_ROWS)

print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (200000, 39)
#    age  gender  income  daily_gaming_hours  weekly_sessions  years_gaming  \
# 0   51  Female    8615                3.68               22            17
# 1   41  Female   39453                5.70               34            16
# 2   27    Male   40466                1.58                8            22
# 3   55    Male   51076                6.11               39            24
# 4   20    Male   86116                3.65               17             0
#
#    sleep_hours  caffeine_intake  exercise_hours  stress_level  anxiety_score  \
# 0         5.26             1.00            0.18             3           4.06
# 1         9.20             0.70            1.44             8           6.76
# 2         7.39             2.24            3.15             3           9.57
# 3         7.99             1.65            2.80             1           4.97
# 4         7.12             1.02            1.01             2           8.73
#
# ...

# %% [markdown]
# ### Justificaci�n de la fuente y cobertura del dataset
#
# | Atributo | Detalle |
# |----------|---------|
# | **Nombre** | Gaming & Mental Health Dataset (10M records, 40 features) |
# | **Fuente** | Dataset sint�tico generado para investigaci�n acad�mica y benchmarking de modelos de ML |
# | **Cobertura** | 10 millones de registros, 40 variables por registro |
# | **Variables** | Demogr�ficas (edad, g�nero, ingresos), conductuales de gaming (horas, sesiones, tipo de juego), indicadores de salud mental (ansiedad, depresi�n, soledad, adicci�n) y factores f�sicos (IMC, horas de sue�o, tiempo de pantalla) |
# | **Restricciones** | Al ser sint�tico, las distribuciones pueden no capturar sesgos de muestreo reales; los resultados deben validarse con datos cl�nicos antes de usarse en decisiones de salud |
# | **Pertinencia** | Cubre directamente las variables necesarias para responder la pregunta anal�tica: comportamiento de juego + indicadores de salud mental en una muestra amplia y balanceada |
# | **Tama�o de muestra usado** | 200,000 registros (2% del total) para equilibrio entre representatividad y tiempo de c�mputo |

# %% [markdown]
# ## 3. Revision inicial
#
# Antes de transformar los datos, es importante conocer su estructura general. Por eso se revisan los tipos de variables, la presencia de valores faltantes y un resumen estadistico basico. Esta revision permite detectar rapidamente posibles problemas de calidad.

# %%
overview = pd.DataFrame({
    "dtype": df.dtypes.astype(str),
    "missing": df.isna().sum(),
    "unique": df.nunique(dropna=False)
}).sort_index()

overview
# Out:
#                               dtype  missing  unique
# academic_performance        float64        0    7504
# addiction_level             float64        0    1001
# age                           int64        0      47
# aggression_score            float64        0    1001
# anxiety_score               float64        0    1001
# back_pain_score             float64        0    1000
# bmi                         float64        0    2741
# caffeine_intake             float64        0    1491
# competitive_rank              int64        0     100
# daily_gaming_hours          float64        0    1956
# depression_score            float64        0    1001
# esports_interest              int64        0      11
# exercise_hours              float64        0    1519
# eye_strain_score            float64        0    1001
# friends_gaming_count          int64        0      50
# gender                          str        0       3
# happiness_score             float64        0    1001
# ...

# %%
numeric_summary = df.describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99]).T
numeric_summary[["min", "1%", "5%", "25%", "50%", "75%", "95%", "99%", "max"]].round(2)
# Out:
#                                 min       1%        5%       25%       50%  \
# age                           13.00    13.00     15.00     24.00     36.00
# income                      5000.00  6449.99  12235.00  41171.00  77285.00
# daily_gaming_hours             0.00     0.30      0.71      1.92      3.36
# weekly_sessions                1.00     1.00      2.00     10.00     20.00
# years_gaming                   0.00     0.00      1.00      6.00     12.00
# sleep_hours                    0.27     3.51      4.53      5.99      7.00
# caffeine_intake                0.00     0.02      0.10      0.57      1.38
# exercise_hours                 0.00     0.02      0.10      0.58      1.38
# stress_level                   1.00     1.00      1.00      3.00      5.00
# anxiety_score                  0.00     0.33      1.71      3.66      5.01
# depression_score               0.00     0.00      0.88      3.32      5.01
# ...

# %% [markdown]
# ## 4. Clasificacion de variables
#
# A continuacion se clasifican las columnas segun su naturaleza: categoricas, binarias, ordinales y continuas. Esta separacion es util porque no todas las variables deben tratarse de la misma forma durante el preprocesamiento.

# %%
categorical_columns = ["gender"]
binary_columns = ["headset_usage"]
ordinal_columns = ["stress_level", "esports_interest", "parental_supervision", "internet_quality"]
continuous_columns = [
    col for col in df.select_dtypes(include=[np.number]).columns
    if col not in binary_columns and col not in ordinal_columns
]

column_groups = {
    "categorical": categorical_columns,
    "binary": binary_columns,
    "ordinal": ordinal_columns,
    "continuous": continuous_columns,
}

pd.Series({key: len(value) for key, value in column_groups.items()}, name="n_columns")
# Out:
# categorical     1
# binary          1
# ordinal         4
# continuous     33
# Name: n_columns, dtype: int64

# %% [markdown]
# ### 4.1 Cardinalidad de variables
#
# La cardinalidad indica cu�ntos valores �nicos tiene cada columna. Es especialmente relevante para detectar variables que podr�an tener problemas de codificaci�n (por ejemplo, una variable num�rica con muy pocos valores �nicos que en realidad es ordinal) o columnas con cardinalidad casi-uno que no aportan informaci�n.

# %%
cardinality = pd.DataFrame({
    "dtype": df.dtypes.astype(str),
    "unique_values": df.nunique(dropna=False),
    "unique_pct": (df.nunique(dropna=False) / len(df) * 100).round(2),
    "sample_values": [df[c].dropna().unique()[:5].tolist() for c in df.columns],
}).sort_values("unique_values")

cardinality
# Out:
#                               dtype  unique_values  unique_pct  \
# headset_usage                 int64              2        0.00
# gender                          str              3        0.00
# stress_level                  int64             10        0.00
# internet_quality              int64             10        0.00
# parental_supervision          int64             11        0.01
# esports_interest              int64             11        0.01
# years_gaming                  int64             25        0.01
# weekly_sessions               int64             39        0.02
# age                           int64             47        0.02
# friends_gaming_count          int64             50        0.02
# toxic_exposure              float64             94        0.05
# violent_games_ratio         float64            100        0.05
# competitive_rank              int64            100        0.05
# mobile_gaming_ratio         float64            101        0.05
# ...

# %% [markdown]
# ## 5. Reglas de validacion
#
# Aunque el dataset no presenta valores faltantes de forma explicita, si contiene observaciones que resultan poco realistas o directamente imposibles. Para enfrentar esto, se definen reglas de validacion por variable, con el fin de identificar valores fuera de rango y tratarlos como faltantes.

# %%
INVALID_RULES = {
    "age": (13, 100),
    "income": (0, 1_000_000),
    "daily_gaming_hours": (0, 24),
    "weekly_sessions": (0, 7 * 24),
    "years_gaming": (0, 80),
    "sleep_hours": (0, 24),
    "caffeine_intake": (0, 50),
    "exercise_hours": (0, 24),
    "stress_level": (1, 10),
    "anxiety_score": (0, 10),
    "depression_score": (0, 10),
    "social_interaction_score": (0, 10),
    "relationship_satisfaction": (0, 10),
    "academic_performance": (0, 100),
    "work_productivity": (0, 100),
    "addiction_level": (0, 10),
    "multiplayer_ratio": (0, 1),
    "toxic_exposure": (0, 1),
    "violent_games_ratio": (0, 1),
    "mobile_gaming_ratio": (0, 1),
    "night_gaming_ratio": (0, 1),
    "weekend_gaming_hours": (0, 72),
    "friends_gaming_count": (0, 10_000),
    "online_friends": (0, 100_000),
    "streaming_hours": (0, 24),
    "esports_interest": (0, 10),
    "headset_usage": (0, 1),
    "microtransactions_spending": (0, 1_000_000),
    "parental_supervision": (0, 10),
    "loneliness_score": (0, 10),
    "aggression_score": (0, 10),
    "happiness_score": (0, 10),
    "bmi": (10, 70),
    "screen_time_total": (0, 24),
    "eye_strain_score": (0, 10),
    "back_pain_score": (0, 10),
    "competitive_rank": (0, 100),
    "internet_quality": (1, 10),
}

invalid_counts = {}
for column, (lower, upper) in INVALID_RULES.items():
    if column in df.columns:
        mask = df[column].notna() & ((df[column] < lower) | (df[column] > upper))
        invalid_counts[column] = int(mask.sum())

pd.Series(invalid_counts).sort_values(ascending=False).to_frame("invalid_count")
# Out:
#                             invalid_count
# screen_time_total                     475
# bmi                                    39
# daily_gaming_hours                     12
# exercise_hours                          1
# income                                  0
# age                                     0
# sleep_hours                             0
# years_gaming                            0
# weekly_sessions                         0
# caffeine_intake                         0
# depression_score                        0
# social_interaction_score                0
# stress_level                            0
# anxiety_score                           0
# work_productivity                       0
# addiction_level                         0
# multiplayer_ratio                       0
# toxic_exposure                          0
# violent_games_ratio                     0
# mobile_gaming_ratio                     0
# relationship_satisfaction               0
# ...

# %% [markdown]
# ## 6. Limpieza de valores invalidos
#
# Una vez definidas las reglas, los valores que no cumplen con los rangos esperados se reemplazan por `NaN`. Esta decision permite conservar la observacion, pero sin arrastrar informacion incorrecta hacia el analisis posterior.

# %%
df_clean = df.copy()

for column, (lower, upper) in INVALID_RULES.items():
    if column in df_clean.columns:
        mask = df_clean[column].notna() & ((df_clean[column] < lower) | (df_clean[column] > upper))
        df_clean.loc[mask, column] = np.nan

df_clean.isna().sum().sort_values(ascending=False).head(15).to_frame("missing_after_cleaning")
# Out:
#                           missing_after_cleaning
# screen_time_total                            475
# bmi                                           39
# daily_gaming_hours                            12
# exercise_hours                                 1
# income                                         0
# gender                                         0
# age                                            0
# sleep_hours                                    0
# years_gaming                                   0
# weekly_sessions                                0
# caffeine_intake                                0
# depression_score                               0
# social_interaction_score                       0
# stress_level                                   0
# anxiety_score                                  0

# %% [markdown]
# ## 7. Tratamiento de outliers
#
# Despues de corregir los valores invalidos, se revisan las variables con distribuciones muy sesgadas o con extremos marcados. En estos casos se aplica winsorizacion por percentiles, lo que reduce la influencia de valores atipicos sin eliminar registros completos.

# %%
skewed_columns = [
    "microtransactions_spending",
    "screen_time_total",
    "daily_gaming_hours",
    "weekend_gaming_hours",
    "caffeine_intake",
    "exercise_hours",
]

clip_summary = []
for column in skewed_columns:
    if column in df_clean.columns:
        lower = df_clean[column].quantile(0.01)
        upper = df_clean[column].quantile(0.99)
        below = int((df_clean[column] < lower).sum())
        above = int((df_clean[column] > upper).sum())
        df_clean[column] = df_clean[column].clip(lower=lower, upper=upper)
        clip_summary.append({
            "column": column,
            "lower_clip": round(float(lower), 3),
            "upper_clip": round(float(upper), 3),
            "clipped_low": below,
            "clipped_high": above,
        })

pd.DataFrame(clip_summary)
# Out:
#                        column  lower_clip  upper_clip  clipped_low  \
# 0  microtransactions_spending        4.91    2296.581         1997
# 1           screen_time_total        1.66      19.460         1990
# 2          daily_gaming_hours        0.30      13.330         1964
# 3        weekend_gaming_hours        0.45      19.950         1982
# 4             caffeine_intake        0.02       9.210         1469
# 5              exercise_hours        0.02       9.260         1432
#
#    clipped_high
# 0          2000
# 1          1989
# 2          1989
# 3          1998
# 4          1999
# 5          1995

# %% [markdown]
# ### 7.1 Visualizaci�n de outliers mediante boxplots
#
# Los boxplots permiten detectar visualmente la dispersi�n y valores extremos. Se muestran las variables con mayor presencia de outliers identificados durante la validaci�n de reglas de negocio.

# %%
outlier_cols = [
    "microtransactions_spending",
    "screen_time_total",
    "daily_gaming_hours",
    "weekend_gaming_hours",
    "caffeine_intake",
    "income",
]

fig, axes = plt.subplots(2, 3, figsize=(14, 8))

for ax, col in zip(axes.flat, outlier_cols):
    if col in df_clean.columns:
        ax.boxplot(df_clean[col].dropna(), vert=True, patch_artist=True,
                   boxprops=dict(facecolor="#a8dadc", color="#457b9d"),
                   medianprops=dict(color="#e63946", linewidth=2),
                   flierprops=dict(marker=".", markersize=2, alpha=0.3))
        ax.set_title(col, fontsize=9)
        ax.set_ylabel("Valor")

plt.suptitle("Distribucion y outliers � variables clave (post-limpieza)", y=1.01, fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Variables derivadas
#
# Ademas de las variables originales, se construyen algunos indicadores compuestos que resumen dimensiones relevantes del problema, como la intensidad de juego, la proporcion de interaccion social en linea y una medida agregada de carga mental.

# %%
df_clean["gaming_intensity_index"] = (
    df_clean["daily_gaming_hours"].fillna(0) * 5 + df_clean["weekend_gaming_hours"].fillna(0)
) / 7

df_clean["online_social_ratio"] = df_clean["online_friends"] / (df_clean["friends_gaming_count"] + 1)
df_clean["gaming_screen_share"] = df_clean["daily_gaming_hours"] / (df_clean["screen_time_total"] + 1e-6)
df_clean["mental_burden_index"] = (
    df_clean["anxiety_score"] + df_clean["depression_score"] + df_clean["stress_level"]
) / 3

df_clean[[
    "gaming_intensity_index",
    "online_social_ratio",
    "gaming_screen_share",
    "mental_burden_index",
]].describe().round(2)
# Out:
#        gaming_intensity_index  online_social_ratio  gaming_screen_share  \
# count               200000.00            200000.00            199525.00
# mean                     3.70                22.39                 0.50
# std                      2.04                46.73                 0.22
# min                      0.23                 0.00                 0.02
# 25%                      2.18                 4.86                 0.32
# 50%                      3.29                 9.76                 0.50
# 75%                      4.79                19.14                 0.67
# max                     12.37               499.00                 1.00
#
#        mental_burden_index
# count            200000.00
# mean                  5.17
# std                   1.41
# min                   0.33
# 25%                   4.17
# 50%                   5.17
# 75%                   6.16
# max                  10.00

# %% [markdown]
# ## 9. Imputacion y codificacion
#
# Para finalizar el preprocesamiento, los valores faltantes numericos se imputan mediante la mediana, ya que es una medida robusta frente a distribuciones asimetricas. Luego, la variable `gender` se transforma con codificacion one-hot para dejar el conjunto de datos preparado para analisis estadistico o modelado.

# %%
df_model = df_clean.copy()

numeric_columns = df_model.select_dtypes(include=[np.number]).columns
for column in numeric_columns:
    if df_model[column].isna().any():
        df_model[column] = df_model[column].fillna(df_model[column].median())

df_model = pd.get_dummies(df_model, columns=["gender"], prefix="gender", dtype=int)

print(df_model.shape)
df_model.head()
# Out:
# (200000, 45)
#     age   income  daily_gaming_hours  weekly_sessions  years_gaming  \
# 0  51.0   8615.0                3.68             22.0          17.0
# 1  41.0  39453.0                5.70             34.0          16.0
# 2  27.0  40466.0                1.58              8.0          22.0
# 3  55.0  51076.0                6.11             39.0          24.0
# 4  20.0  86116.0                3.65             17.0           0.0
#
#    sleep_hours  caffeine_intake  exercise_hours  stress_level  anxiety_score  \
# 0         5.26             1.00            0.18           3.0           4.06
# 1         9.20             0.70            1.44           8.0           6.76
# 2         7.39             2.24            3.15           3.0           9.57
# 3         7.99             1.65            2.80           1.0           4.97
# 4         7.12             1.02            1.01           2.0           8.73
#
#    depression_score  social_interaction_score  relationship_satisfaction  \
# ...

# %% [markdown]
# ## 10. Graficos relevantes para el analisis
#
# En esta seccion no se busca mostrar todos los graficos posibles, sino aquellos que aportan informacion clara para una primera interpretacion del dataset. Se priorizan visualizaciones que permitan describir la muestra y explorar relaciones entre juego, bienestar y salud mental.

# %% [markdown]
# ### 10.1 Distribucion general de la muestra
#
# El primer grafico resume dos aspectos basicos del conjunto de datos: la composicion por genero y la distribucion etaria. Esta visualizacion permite describir rapidamente a la poblacion observada antes de entrar en relaciones mas especificas.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

df["gender"].value_counts().plot(kind="bar", ax=axes[0], color=["#1f77b4", "#ff7f0e", "#2ca02c"])
axes[0].set_title("Distribucion por genero")
axes[0].set_xlabel("Genero")
axes[0].set_ylabel("Cantidad")

axes[1].hist(df["age"], bins=20, color="#33658a", edgecolor="white")
axes[1].set_title("Distribucion de edad")
axes[1].set_xlabel("Edad")
axes[1].set_ylabel("Frecuencia")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10.2 Distribucion de variables de salud mental
#
# A continuacion se observan cuatro puntajes centrales del dataset. Este paso sirve para identificar si las distribuciones parecen equilibradas, concentradas en ciertos rangos o sesgadas hacia valores extremos.

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
score_columns = ["anxiety_score", "depression_score", "addiction_level", "happiness_score"]
score_colors = ["#bc4749", "#6a4c93", "#f4a259", "#4d908e"]

for ax, column, color in zip(axes.flat, score_columns, score_colors):
    ax.hist(df_clean[column], bins=20, color=color, edgecolor="white")
    ax.set_title(column)
    ax.set_xlabel(column)
    ax.set_ylabel("Frecuencia")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10.3 Relacion entre horas de juego y nivel de adiccion
#
# Este grafico permite evaluar si existe una tendencia general entre el tiempo diario de juego y el nivel de adiccion reportado. Se utiliza una muestra de puntos para facilitar la lectura y se agrega una linea de tendencia como apoyo visual.

# %%
scatter_df = df_clean[["daily_gaming_hours", "addiction_level"]].dropna().sample(15000, random_state=42)
x = scatter_df["daily_gaming_hours"].to_numpy()
y = scatter_df["addiction_level"].to_numpy()
slope, intercept = np.polyfit(x, y, 1)

plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.2, s=16, color="#2a9d8f")
x_line = np.linspace(x.min(), x.max(), 100)
plt.plot(x_line, slope * x_line + intercept, color="#e63946", linewidth=2)
plt.title("Horas de juego diarias vs nivel de adiccion")
plt.xlabel("Daily gaming hours")
plt.ylabel("Addiction level")
plt.show()

# %% [markdown]
# ### 10.4 Correlaciones entre variables relevantes
#
# El mapa de correlacion resume la intensidad y direccion de las asociaciones lineales entre variables seleccionadas. No implica causalidad, pero resulta util para detectar patrones consistentes y posibles grupos de variables relacionadas.

# %%
heatmap_columns = [
    "daily_gaming_hours",
    "sleep_hours",
    "stress_level",
    "anxiety_score",
    "depression_score",
    "addiction_level",
    "happiness_score",
    "loneliness_score",
    "social_interaction_score",
    "screen_time_total",
    "weekend_gaming_hours",
]

corr = df_clean[heatmap_columns].corr()

plt.figure(figsize=(10, 8))
plt.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1)
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha="right")
plt.yticks(range(len(corr.index)), corr.index)
plt.title("Mapa de correlacion de variables relevantes")

for row in range(corr.shape[0]):
    for col in range(corr.shape[1]):
        plt.text(col, row, f"{corr.iloc[row, col]:.2f}", ha="center", va="center", fontsize=8)

plt.colorbar(fraction=0.046, pad=0.04)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10.5 Variables mas asociadas con `addiction_level`
#
# Finalmente, se muestran las variables con mayor correlacion absoluta respecto de `addiction_level`. Esta visualizacion ayuda a priorizar que atributos conviene revisar con mayor detalle en un analisis posterior o en una etapa de modelado.

# %%
top_corr = df_clean.corr(numeric_only=True)["addiction_level"].drop("addiction_level").abs().sort_values(ascending=False).head(10).sort_values()

plt.figure(figsize=(9, 6))
plt.barh(top_corr.index, top_corr.values, color="#577590")
plt.title("Top correlaciones absolutas con addiction_level")
plt.xlabel("Correlacion absoluta")
plt.ylabel("Variable")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10.6 Relaci�n entre estr�s y depresi�n por nivel de adicci�n
#
# Este gr�fico cruza dos variables de salud mental clave (`stress_level` y `depression_score`) y colorea los puntos seg�n el nivel de adicci�n. Permite identificar si existe un patr�n de co-ocurrencia entre estr�s elevado, depresi�n y mayor adicci�n al juego.

# %%
sample_stress = df_clean[["stress_level", "depression_score", "addiction_level"]].dropna().sample(10000, random_state=42)

plt.figure(figsize=(9, 6))
scatter = plt.scatter(
    sample_stress["stress_level"],
    sample_stress["depression_score"],
    c=sample_stress["addiction_level"],
    cmap="YlOrRd",
    alpha=0.4,
    s=14
)
plt.colorbar(scatter, label="Nivel de adiccion")
plt.title("Estres vs Depresion, coloreado por nivel de adiccion")
plt.xlabel("Nivel de estres")
plt.ylabel("Puntaje de depresion")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Data Quality Report (DQR)
#
# El Data Quality Report es un documento estructurado que eval�a el estado de calidad del dataset antes y despu�s del preprocesamiento. Se analiza en seis dimensiones: **completitud**, **validez**, **consistencia**, **unicidad**, **cobertura de variables** y **riesgos/limitaciones**.

# %%
import warnings
warnings.filterwarnings("ignore")

# --- 1. Completitud ---
missing_raw = df.isna().sum()
missing_clean = df_model.isna().sum()

# --- 2. Validez (valores fuera de rango) ---
invalidos_total = 0
invalidos_por_col = {}
for col, (lo, hi) in INVALID_RULES.items():
    if col in df.columns:
        n = int(((df[col] < lo) | (df[col] > hi)).sum())
        invalidos_por_col[col] = n
        invalidos_total += n

invalidity_report = pd.Series(invalidos_por_col, name="valores_invalidos").sort_values(ascending=False)

# --- 3. Unicidad (duplicados) ---
n_duplicados = int(df.duplicated().sum())
pct_duplicados = round(n_duplicados / len(df) * 100, 4)

# --- 4. Consistencia (variables derivadas coherentes) ---
neg_gaming_share = int((df_clean["gaming_screen_share"] < 0).sum()) if "gaming_screen_share" in df_clean.columns else 0
neg_social_ratio = int((df_clean["online_social_ratio"] < 0).sum()) if "online_social_ratio" in df_clean.columns else 0

# --- Mostrar resumen ---
print("=" * 55)
print("DATA QUALITY REPORT")
print("=" * 55)
print(f"\n[1] COMPLETITUD")
print(f"    Filas totales (muestra): {len(df):,}")
print(f"    Columnas originales:     {df.shape[1]}")
print(f"    Nulos en dataset raw:    {int(missing_raw.sum()):,}")
print(f"    Nulos post-preproc:      {int(missing_clean.sum()):,}")
print(f"\n[2] VALIDEZ")
print(f"    Valores invalidos total: {invalidos_total:,}")
print(f"    Columnas afectadas:      {sum(1 for v in invalidos_por_col.values() if v > 0)}")
validos_con_error = invalidity_report[invalidity_report > 0]
if validos_con_error.empty:
    print("    Sin columnas con valores fuera de rango.")
else:
    print(validos_con_error.to_string())
print(f"\n[3] UNICIDAD")
print(f"    Filas duplicadas:        {n_duplicados:,}  ({pct_duplicados}% del total)")
print(f"\n[4] CONSISTENCIA")
print(f"    gaming_screen_share < 0: {neg_gaming_share}")
print(f"    online_social_ratio < 0: {neg_social_ratio}")
print(f"\n[5] COBERTURA DE VARIABLES")
print(f"    Variables continuas:     {len(continuous_columns)}")
print(f"    Variables ordinales:     {len(ordinal_columns)}")
print(f"    Variables binarias:      {len(binary_columns)}")
print(f"    Variables categoricas:   {len(categorical_columns)}")
print(f"\n[6] RIESGOS Y LIMITACIONES")
print("    - Dataset sintetico: distribuciones artificiales, sin sesgos de muestreo real.")
print("    - Sin dimension temporal: no permite analisis longitudinal.")
print("    - Variables ordinales tratadas como continuas en correlaciones.")
print("    - Winsorizacion puede suavizar patrones extremos clinicamente relevantes.")
print("    - Sin informacion geografica ni cultural para segmentacion regional.")
print("=" * 55)
# Out:
# ...
# DATA QUALITY REPORT
# ...
#
# [1] COMPLETITUD
#     Filas totales (muestra): 200,000
#     Columnas originales:     39
#     Nulos en dataset raw:    0
#     Nulos post-preproc:      0
#
# [2] VALIDEZ
#     Valores invalidos total: 527
#     Columnas afectadas:      4
# screen_time_total     475
# bmi                    39
# daily_gaming_hours     12
# exercise_hours          1
#
# [3] UNICIDAD
#     Filas duplicadas:        0  (0.0% del total)
#
# [4] CONSISTENCIA
#     gaming_screen_share < 0: 0
#     online_social_ratio < 0: 0
#
# [5] COBERTURA DE VARIABLES
#     Variables continuas:     33
#     Variables ordinales:     4
#     Variables binarias:      1
#     Variables categoricas:   1
#
# [6] RIESGOS Y LIMITACIONES
#     - Dataset sintetico: distribuciones artificiales, sin sesgos de muestreo real.
#     - Sin dimension temporal: no permite analisis longitudinal.
#     - Variables ordinales tratadas como continuas en correlaciones.
# ...

# %% [markdown]
# ## 13. Arquitectura del pipeline de datos
#
# El siguiente diagrama representa el flujo completo de datos desde la fuente original hasta el dataset listo para modelado. Cada capa est� documentada con sus transformaciones y criterios de trazabilidad.
#
# ```mermaid
# flowchart TD
#     A[("Fuente\nDataset sintetico\n10M x 40 features\n.csv.gz")] --> B
#
#     subgraph INGESTA["Ingesta"]
#         B["Carga con pd.read_csv\nmuestra configurable nrows\nformato comprimido .gz"]
#     end
#
#     B --> C
#
#     subgraph RAW["Capa Raw"]
#         C["DataFrame crudo\nsin transformaciones\nRegistro shape y tipos"]
#     end
#
#     C --> D
#
#     subgraph PERFILADO["Perfilado y EDA"]
#         D["Revision inicial\ndtypes, missing, cardinalidad"]
#         D --> D1["Estadisticos descriptivos\npercentiles 1pct-99pct"]
#         D1 --> D2["Clasificacion de variables\ncontinuas, ordinales, binarias, categoricas"]
#     end
#
#     D2 --> E
#
#     subgraph STAGING["Staging / Validacion"]
#         E["Reglas de negocio\nINVALID_RULES por variable"]
#         E --> E1["Reemplazo valores invalidos\npor NaN"]
#     end
#
#     E1 --> F
#
#     subgraph CURATED["Capa Curated"]
#         F["Tratamiento outliers\nWinsorizacion p1-p99"]
#         F --> F1["Variables derivadas\ngaming_intensity_index\nonline_social_ratio\ngaming_screen_share\nmental_burden_index"]
#         F1 --> F2["Imputacion nulos\nMediana numerica"]
#         F2 --> F3["Codificacion categorica\nOne-hot encoding gender"]
#     end
#
#     F3 --> G
#
#     subgraph CONSUMO["Capa de Consumo"]
#         G["dataset_preprocessed.csv\nDataset listo para modelado"]
#         G --> G1["Trazabilidad\ndataset_profile.json\npreprocessing_log.json"]
#     end
#
#     G --> H
#
#     subgraph MODELADO["Tarea 2"]
#         H["Feature engineering\nSeleccion variables\nModelado predictivo"]
#     end
#
#     style INGESTA fill:#e8f4f8,stroke:#457b9d
#     style RAW fill:#fff3e0,stroke:#f4a261
#     style PERFILADO fill:#e8f5e9,stroke:#2d6a4f
#     style STAGING fill:#fce4ec,stroke:#c9184a
#     style CURATED fill:#f3e5f5,stroke:#7b2d8b
#     style CONSUMO fill:#e0f2f1,stroke:#00695c
#     style MODELADO fill:#f5f5f5,stroke:#999
# ```
#
# ### Criterios de versionado y reproducibilidad
#
# | Criterio | Implementaci�n |
# |----------|---------------|
# | **Reproducibilidad** | Script `preprocess_dataset.py` parametrizable; notebook ejecutable linealmente |
# | **Trazabilidad** | `preprocessing_log.json` registra cada transformaci�n con conteos |
# | **Versionado de datos** | Archivo original `.csv.gz` nunca se modifica; outputs con nombres configurables |
# | **Configurabilidad** | CLI: `--sample-rows`, `--scale-continuous`, `--output-csv`, `--skip-save-processed` |
# | **Entorno** | Dependencias en `requirements.txt`: numpy, pandas, matplotlib, scikit-learn |

# %% [markdown]
# ## 14. Guardado opcional del dataset procesado
#
# La siguiente celda exporta una version limpia y transformada del dataset. Este archivo puede utilizarse como insumo para nuevos analisis o como base para construir modelos predictivos.

# %%
if SAVE_PROCESSED:
    df_model.to_csv(PROCESSED_OUTPUT, index=False)
    print(f"Archivo guardado en: {PROCESSED_OUTPUT.resolve()}")
else:
    print("Guardado desactivado")
# Out:
# Archivo guardado en: C:\Users\mronc\Documents\GitHub\ciencia_de_datos\processed\dataset_preprocessed.csv

# %% [markdown]
# ## 15. Conclusiones
#
# A traves de este notebook se desarrollo un flujo de preprocesamiento claro y reproducible, compuesto por revision inicial, validacion de rangos, tratamiento de outliers, generacion de variables derivadas e imputacion de faltantes. Ademas, se incorporaron visualizaciones orientadas a describir la muestra y explorar relaciones entre intensidad de juego y variables de salud mental.
#
# Como siguiente paso, si el objetivo del trabajo incluye modelado predictivo, seria recomendable encapsular este procedimiento en un `Pipeline` de `scikit-learn` para separar correctamente entrenamiento y prueba, y asi evitar fuga de informacion.
